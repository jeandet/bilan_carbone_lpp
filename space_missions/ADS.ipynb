# %%
import pickle
from datetime import datetime
from types import SimpleNamespace

import ads
import pandas as pds
from pint import Quantity
from tqdm import tqdm


ads.config.token = "place your ADS API token here"

# %%
def build_query(**kwargs):
    return " ".join([f"{key}:{value}" for key, value in kwargs.items()])


def get_all_publications(**kwargs):
    return list(
        ads.SearchQuery(
            q=build_query(**kwargs),
            rows=2000,
            max_pages=100,
            fl=[
                "id",
                "property",
                "bibcode",
                "title",
                "citation_count",
                "citation",
                "database",
                "author",
                "aff",
                "doi",
                "year",
            ],
        )
    )


def make_database(missions):
    return SimpleNamespace(
        **{
            name: get_all_publications(**mission.query)
            for name, mission in tqdm(missions.__dict__.items())
        }
    )


def filter_refereed(pub_list):
    return list(filter(lambda p: "REFEREED" in p.property or [], pub_list))


def filter_affiliation(pub_list, name_list):
    def has_lpp_affiliation(pub) -> bool:
        def is_lpp(aff: str) -> bool:
            return any([name.lower() in aff.lower() for name in name_list])

        if pub.aff is None:
            print(
                f"Got none: pub.aff {pub.id}, {pub.doi}, {pub.title}, {pub.database}, {pub.property}"
            )
        return any(filter(lambda affiliation: is_lpp(affiliation or []), pub.aff or []))

    return filter(lambda p: has_lpp_affiliation(p), pub_list)


def filter_publication_year(pub_list, year: int):
    return filter(lambda p: str(year) in p.year, pub_list)


def filter_publication_until_year(pub_list, year: int):
    return filter(lambda p: year > int(p.year), pub_list)

# %%
Quantity("620 * 2  kg")
# Out:
# 1240 <Unit('kilogram')>

# %% [markdown]
# # Missions database, add or remove mission here:
#
# This database is used to generate queries for ADS and get all article for each entry (Mission) in the database.
#
# bilan.total_publications_LPP_2021[1][0].titleEntry specification:
# - launch_date must be a datetime
# - query can be anything compatible with ADS query
# - add suspicious=True if you feel like request results doesn't match what you would expect

# %%
missions = SimpleNamespace(
    PSP=SimpleNamespace(
        name="Parker Solar Probe",
        launch_date=datetime(2018, 8, 12),
        query={"body": '"Parker Solar Probe" OR "NASA PSP"'},
        mass=Quantity("685 kg"),
    ),
    SDO=SimpleNamespace(
        name="Solar Dynamics Observatory",
        launch_date=datetime(2010, 2, 11),
        query={
            "body": '"Solar Dynamics Observatory" OR "HMI/SDO" OR "AIA/SDO" OR "EVE/SDO"'
        },
        mass=Quantity("3,100 kg"),
    ),
    SolarOrbiter=SimpleNamespace(
        name="Solar Orbiter",
        launch_date=datetime(2020, 2, 10),
        query={
            "body": '"Solar Orbiter" OR "SOLO/RPW" OR "SOLO/LFR"'
        },
        mass=Quantity("1,800 kg"),
    ),
    SOHO=SimpleNamespace(
        name="Solar and Heliospheric Observatory",
        launch_date=datetime(1995, 12, 2),
        query={"body": '"SOHO" OR "Solar and Heliospheric Observatory"'},
        mass=Quantity("1,850 kg"),
    ),
    MMS=SimpleNamespace(
        name="Magnetospheric Multiscale Mission",
        launch_date=datetime(2015, 3, 13),
        query={"body": '"Magnetospheric Multiscale" OR "NASA/MMS"'},
        mass=Quantity("1,360 kg"),
    ),
    Cluster=SimpleNamespace(
        name="Cluster",
        launch_date=datetime(2000, 7, 16),
        query={
            "body": '"Cluster spacecraft" OR "Cluster mission" OR "Cluster satellite constellation"'
        },
        mass=Quantity("1,200 kg"),
    ),
    Cassini=SimpleNamespace(
        name="Cassini",
        launch_date=datetime(1997, 10, 15),
        query={
            "body": '"Cassini mission" OR "Cassini spacecraft" OR "Cassini orbiter" OR "Cassini-Huygens" OR "Huygens module" OR ="Huygens probe" OR "Huygens lander"'
        },
        mass=Quantity("5,712 kg"),
    ),
    DoubleStar=SimpleNamespace(
        name="DoubleStar",
        launch_date=datetime(2003, 12, 29),
        query={
            "body": '"Double Star spacecrafts" OR "Double Star satellites" OR "Double Star TC" OR "TC-1 satellite" OR "TC-2 satellite"'
        },
        mass=Quantity("560 kg"),
    ),
    Demeter=SimpleNamespace(
        name="Demeter",
        launch_date=datetime(2004, 6, 29),
        query={
            "body": '"DEMETER spacecraft" OR "DEMETER mission" OR "DEMETER satellite"'
        },
        mass=Quantity("130 kg"),
    ),
    STEREO=SimpleNamespace(
        name="STEREO",
        launch_date=datetime(2006, 10, 26),
        query={"body": '"STEREO"'},
        mass=Quantity("620 * 2  kg"),
    ),
    ACE=SimpleNamespace(
        name="Advanced Composition Explorer",
        launch_date=datetime(1997, 8, 25),
        query={
            "body": '"Advanced Composition Explorer" OR "ACE mission" OR "ACE spacecraft" OR ="ACE satellite"'
        },
        mass=Quantity("757 kg"),
    ),
    IMP_8=SimpleNamespace(
        name="IMP-8",
        launch_date=datetime(1973, 11, 26),
        query={
            "body": '"Interplanetary Monitoring Platform 8" OR "IMP-8" OR "IMP-J" OR "Explorer 50"'
        },
        mass=Quantity("371  kg"),
    ),
    Geotail=SimpleNamespace(
        name="Geotail",
        launch_date=datetime(1992, 7, 24),
        query={"body": '"Geotail"'},
        mass=Quantity("980 kg"),
    ),
    Wind=SimpleNamespace(
        name="Wind",
        launch_date=datetime(1994, 12, 1),
        query={
            "body": '"Wind mission" OR "Wind spacecraft" OR "Wind satellite" OR "WIND/WAVES" OR "Wind/3DP" OR "Wind/MFI" OR "Wind/SWE" OR "Wind/KONUS" OR "Wind/TGRS" OR "Wind/EPACT" OR "Wind/SMS"'
        },
        mass=Quantity("1,250 kg"),
    ),
    TIMED=SimpleNamespace(
        name="TIMED",
        launch_date=datetime(2001, 12, 7),
        query={"body": '"TIMED"'},
        mass=Quantity("660 kg"),
    ),
    VEX=SimpleNamespace(
        name="Venus Express",
        launch_date=datetime(2015, 1, 18),
        query={
            "body": '"Venus Express" OR "VEX mission" OR "VEX spacecraft" OR "VEX probe"'
        },
        mass=Quantity("1,270 kg"),
    ),
    THEMIS=SimpleNamespace(
        name="THEMIS",
        launch_date=datetime(2007, 2, 17),
        query={
            "body": '"THEMIS mission" OR "THEMIS spacecraft" OR "THEMIS-A" OR "THEMIS-B" OR "THEMIS probe" OR "ARTEMIS-P1"'
        },
        mass=Quantity("126 kg * 5"),
    ),
    Juno=SimpleNamespace(
        name="Juno",
        launch_date=datetime(2011, 8, 5),
        query={
            "body": '"Juno mission"  OR "Juno spacecraft" OR "Juno orbiter" OR "NASA/Juno" OR "Juno MWR" OR "Juno JIRAM" OR "Juno MAG" OR "Juno GS" OR "Juno JADE" OR "Juno JEDI" OR "Juno Waves" OR "Juno UVS" OR "Juno JCM"'
        },
        mass=Quantity("3,625 kg"),
    ),
    Rosetta=SimpleNamespace(
        name="Rosetta",
        launch_date=datetime(2004, 3, 2),
        query={
            "body": '"Rosetta mission" OR "Rosetta spacecraft" OR "Rosetta Churyumov-Gerasimenko" OR "Philae Churyumov-Gerasimenko"'
        },
        mass=Quantity("3,000 kg"),
    ),
    Galileo=SimpleNamespace(
        name="Galileo",
        launch_date=datetime(1989, 10, 18),
        query={
            "body": '"Galileo mission" OR "Galileo spacecraft" OR "Galileo orbiter" OR "NASA/Galileo"  OR "Galileo entry probe"'
        },
        mass=Quantity("2,560 kg"),
    ),
    Gaia=SimpleNamespace(
        name="Gaia",
        launch_date=datetime(2013, 12, 19),
        query={"body": '"GAIA"'},
        mass=Quantity("2,029 kg"),
    ),
    MEX=SimpleNamespace(
        name="Mars Express",
        launch_date=datetime(2003, 6, 2),
        query={
            "body": '"Mars Express" OR "MEX mission" OR "MEX spacecraft" OR "MEX probe"'
        },
        mass=Quantity("1,123 kg"),
    ),
    Dawn=SimpleNamespace(
        name="Dawn",
        launch_date=datetime(2007, 11, 27),
        query={
            "body": '"Dawn mission" OR "Dawn spacecraft" OR "Dawn orbiter" OR "NASA/Dawn" OR "Dawn Vesta" OR "Dawn Ceres"'
        },
        mass=Quantity("1,217.7 kg"),
    ),
    HST=SimpleNamespace(
        name="HST",
        launch_date=datetime(1990, 3, 24),
        query={"body": '"HST"'},
        suspicious=True,
        mass=Quantity("11,110 kg"),
    ),
    Chandra=SimpleNamespace(
        name="Chandra",
        launch_date=datetime(1999, 7, 23),
        query={
            "body": '"Chandra X-ray Observatory" OR "CXO" OR "Chandra mission" OR "Chandra satellite" OR "Chandra telescope" OR "Chandra spacecraft" OR "Chandra observatory" OR "Chandra X-ray" OR "Chandra data" OR "Chandra image" OR "Chandra spectrum" OR "NASA/Chandra" OR "Chandra/ACIS" OR "Chandra/HRC" OR "Chandra/LETG" OR "Chandra/HETG"'
        },
        suspicious=True,
        mass=Quantity("5,860 kg"),
    ),
)

CO2_mass_coefficient = Quantity("50000 t / t")

# %% [markdown]
# # Build and save publication database

# %%
all_publications = make_database(missions=missions)

with open(f"all_publications-{datetime.now().isoformat()}.pkl", "wb") as f:
    f.write(pickle.dumps(all_publications))
# Out:
# 100%|██████████| 25/25 [15:31<00:00, 37.25s/it]

# %% [markdown]
# # Load from local file to avoid repeating the request (if notebook crashed or for any reason...)

# %%
all_publications = pickle.load(
    open("all_publications-2023-01-20T15:38:55.867090.pkl", "rb")
)

# %% [markdown]
# # Actual analysis

# %%
def build_table(missions_db, publications, labs, years):
    years = sorted(years)
    bilan = SimpleNamespace(
        mission=[],
        mission_footprint=[],
        total_publications=[],
        anual_footprint=[],
        years_since_launch=[],
        footprint_per_paper=[],
        **{f"total_publications_LPP_{year}": [] for year in years},
    )
    for lab in labs:
        bilan.__dict__[f"total_publications_{lab.name}"] = []
        for year in years:
            bilan.__dict__[f"total_publications_{lab.name}_{year}"] = []
            bilan.__dict__[f"CO2e_mass_{lab.name}_{year}"] = []

    for mission_name, publications in publications.__dict__.items():

        mission = missions_db.__dict__[mission_name]

        years_since_launch = (
            datetime(max(years), 12, 31) - mission.launch_date
        ).days / 365
        bilan.years_since_launch.append(years_since_launch)

        mission_footprint = mission.mass * CO2_mass_coefficient
        bilan.mission_footprint.append(round(mission_footprint.to("t").magnitude))

        bilan.mission.append(mission_name)
        refered_publications = list(
            filter_publication_until_year(filter_refereed(publications), max(years) + 1)
        )
        bilan.total_publications.append(len(refered_publications))

        anual_footprint = mission_footprint / years_since_launch
        bilan.anual_footprint.append(round(anual_footprint.to("t").magnitude))

        footprint_per_paper = mission_footprint / len(refered_publications)
        bilan.footprint_per_paper.append(round(footprint_per_paper.to("t").magnitude))

        for lab in labs:
            total_lab = list(
                filter_affiliation(refered_publications, lab.possible_names)
            )
            bilan.__dict__[f"total_publications_{lab.name}"].append(len(total_lab))

            for year in years:
                total_publications = len(
                    list(filter_publication_year(refered_publications, year))
                )
                total_lab_publications = len(
                    list(filter_publication_year(total_lab, year))
                )
                if total_publications > 0 and mission.launch_date.year <= year:
                    bilan.__dict__[f"total_publications_{lab.name}_{year}"].append(
                        total_lab_publications
                    )
                    bilan.__dict__[f"CO2e_mass_{lab.name}_{year}"].append(
                        round(
                            (total_lab_publications * footprint_per_paper)
                            .to("t")
                            .magnitude
                        )
                    )
                else:
                    bilan.__dict__[f"total_publications_{lab.name}_{year}"].append(
                        total_lab_publications
                    )
                    bilan.__dict__[f"CO2e_mass_{lab.name}_{year}"].append(0)

    return pds.DataFrame.from_dict(bilan.__dict__).set_index("mission")

# %%
df = build_table(
    missions,
    all_publications,
    [
        SimpleNamespace(
            name="LPP", possible_names=["LPP", "laboratoire de physique des plasmas"]
        ),
        SimpleNamespace(
            name="IRAP", possible_names=["IRAP", "INSTITUT DE RECHERCHE EN ASTROPHYSIQUE ET PLANÉTOLOGIE"]
        ),
        SimpleNamespace(
            name="LPC2E", possible_names=["LPC2E", "Laboratoire de Physique et Chimie de l’Environnement et de l’Espace"]
        )
    ],
    range(2019, 2022),
)
df
# Out:
# Got none: pub.aff 17661366, ['10.1038/d41586-019-03710-1'], ['Parker probe kicks off a golden age for solar exploration'], ['astronomy', 'general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 20896698, ['10.1038/d41586-021-03708-8'], ["Imperilled glacier, COVID immunity and `touching' the Sun"], ['astronomy'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 18779649, ['10.1038/d41586-020-00360-6'], ['CRISPR enhancement, coronavirus source and a controversial appointment'], ['astronomy', 'general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 15269145, ['10.1038/d41586-018-05938-9'], ['Plagiarism rules, discrimination settlements and asteroid close-up'], ['general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19818323, None, ['Here and There'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 15508609, None, ['2018 February meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 20889448, ['10.1103/Physics.14.179'], ['Highlights of the Year'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19818336, None, ['2020 March Meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 17661366, ['10.1038/d41586-019-03710-1'], ['Parker probe kicks off a golden age for solar exploration'], ['astronomy', 'general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 20896698, ['10.1038/d41586-021-03708-8'], ["Imperilled glacier, COVID immunity and `touching' the Sun"], ['astronomy'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 18779649, ['10.1038/d41586-020-00360-6'], ['CRISPR enhancement, coronavirus source and a controversial appointment'], ['astronomy', 'general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 15269145, ['10.1038/d41586-018-05938-9'], ['Plagiarism rules, discrimination settlements and asteroid close-up'], ['general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19818323, None, ['Here and There'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 15508609, None, ['2018 February meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 20889448, ['10.1103/Physics.14.179'], ['Highlights of the Year'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19818336, None, ['2020 March Meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 17661366, ['10.1038/d41586-019-03710-1'], ['Parker probe kicks off a golden age for solar exploration'], ['astronomy', 'general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 20896698, ['10.1038/d41586-021-03708-8'], ["Imperilled glacier, COVID immunity and `touching' the Sun"], ['astronomy'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 18779649, ['10.1038/d41586-020-00360-6'], ['CRISPR enhancement, coronavirus source and a controversial appointment'], ['astronomy', 'general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 15269145, ['10.1038/d41586-018-05938-9'], ['Plagiarism rules, discrimination settlements and asteroid close-up'], ['general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19818323, None, ['Here and There'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 15508609, None, ['2018 February meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 20889448, ['10.1103/Physics.14.179'], ['Highlights of the Year'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19818336, None, ['2020 March Meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2566351, ['10.1007/s11207-008-9168-x'], ['Preface: A Topical Issue on Solar Image Analysis and Visualization'], ['astronomy'], ['ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 1122088, None, ['William Herschel, 1738-1822'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2763708, ['10.3367/UFNe.0182.201209e.0999'], ['Challenges in astrophysics (Scientific session of the Physical Sciences Division of the Russian Academy of Sciences, 25 January 2012)'], ['astronomy', 'physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 9813486, ['10.1119/1.4928369'], ['Magnetic field lines on the Sun'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 776098, None, ['2014 February meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2711577, None, ['RAS Meeting of 2100 May 13'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4412281, ['10.1016/0010-4655(82)90036-4'], ['Erratum notice'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 18918317, ['10.1103/Physics.7.s65'], ['Unexpected Impact from Medium-Sized Solar Flare'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5530417, ['10.1016/0010-4655(92)90157-T'], ['Erratum notice'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 15268446, ['10.1016/S0262-4079(18)31290-9'], ['Tornadoes on sun threaten Earth'], ['general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 8924876, ['10.3367/UFNe.0180.201009f.0973'], ['CONFERENCES AND SYMPOSIA Commemoration of the 85th birthday of S I Syrovatskii(Scientific session of the Physical Sciences Division of the Russian Academy of Sciences, 26 May 2010)'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 2814462, None, ['Book reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 300369, None, ['Book reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5306731, ['10.1016/0895-9811(90)90010-X'], ['Acknowledge to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1584863, None, ['Errata: Sov. Astron. Lett. 10, No. 3 (1984)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 20790656, None, ['2020 December Meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2354243, None, ['2004 January meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1039413, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1668284, None, ['Society Business'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2354253, None, ['2004 February meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5580414, ['10.1016/0895-9811(92)90032-T'], ['Acknowledgement to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5438171, ['10.1016/0895-9811(91)90011-9'], ['Acknowledgement to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1710964, None, ['Pulsars'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047797, None, ['Princeton Observatory Publications'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047725, None, ['A Correction'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047679, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047662, None, ['Observations on Shadow bands'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1678393, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 8924931, ['10.3367/UFNe.0180.201006g.0647'], ['CONFERENCES AND SYMPOSIA:  Nuclear physics, lasers, and medicine(Scientific session of the General Meeting of the Physical Sciences Division of the Russian Academy of Sciences, 14 December 2009)'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1001989, None, ['Report of the Council on the Work of the Session, October 1, 1907, to September 30, 1908, to be Presented to the Members of the Association at the Annual General Meeting, October 28, 1908'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5580479, ['10.1016/0895-9811(92)90021-P'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5580381, ['10.1016/0895-9811(92)90050-9'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5580375, ['10.1016/0895-9811(92)90011-M'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5864810, ['10.1016/0895-9811(94)90037-X'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1017554, None, ['Notes for Observers'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2215443, None, ['Annual Report of the SAAO 1999'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 920385, ['10.1002/asna.18610540202'], ['Beobachtungen der Sonnenfinsterniss vom 18. Juli d. J. in Desierto de las Palmas, angestellt von der Commission der Königl. Sternwarte zu Madrid. Aus der "Comunicacion del Director del Observatorio de Madrid al Comisario régio del Mismo", vom Herrn Verfasser für die Astr. Nachr. mitgetheilt'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 7264530, ['10.1016/S0375-9474(03)00637-7'], ['Appendix: Members of collaborations'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1579917, None, ['Royal Greenwich Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1611103, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1713865, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4276792, ['10.1016/0370-1573(80)90173-8'], ['Physics results'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19142897, ['10.1016/0273-1177(87)90389-9'], ['Current status of satellite remote sensing and related data systems'], ['astronomy'], ['ARTICLE', 'ESOURCE', 'REFEREED', 'TOC']
# Got none: pub.aff 1039404, None, ['Variable Star Observations: Variable star observations, April 20; Monthly report of the American Association of Variable Star Observers'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 3913934, ['10.1016/S0090-3752(76)80053-1'], ['Key numbers and key words'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 3996060, ['10.1016/S0090-3752(77)80003-3'], ['Reaction index'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1856165, None, ['55. Annual Meeting of the Meteoritical Society, Copenhagen (Denmark), 27 - 31 Jul 1992.'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4860690, ['10.1016/0370-2693(86)91663-1'], ['Abbreviations used in the full listings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1942577, ['10.1007/BF00712488'], ['Preface'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED', 'TOC']
# Got none: pub.aff 3831377, ['10.1016/S0090-3752(75)80025-1'], ['Reaction index'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 2566351, ['10.1007/s11207-008-9168-x'], ['Preface: A Topical Issue on Solar Image Analysis and Visualization'], ['astronomy'], ['ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 1122088, None, ['William Herschel, 1738-1822'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2763708, ['10.3367/UFNe.0182.201209e.0999'], ['Challenges in astrophysics (Scientific session of the Physical Sciences Division of the Russian Academy of Sciences, 25 January 2012)'], ['astronomy', 'physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 9813486, ['10.1119/1.4928369'], ['Magnetic field lines on the Sun'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 776098, None, ['2014 February meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2711577, None, ['RAS Meeting of 2100 May 13'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4412281, ['10.1016/0010-4655(82)90036-4'], ['Erratum notice'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 18918317, ['10.1103/Physics.7.s65'], ['Unexpected Impact from Medium-Sized Solar Flare'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5530417, ['10.1016/0010-4655(92)90157-T'], ['Erratum notice'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 15268446, ['10.1016/S0262-4079(18)31290-9'], ['Tornadoes on sun threaten Earth'], ['general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 8924876, ['10.3367/UFNe.0180.201009f.0973'], ['CONFERENCES AND SYMPOSIA Commemoration of the 85th birthday of S I Syrovatskii(Scientific session of the Physical Sciences Division of the Russian Academy of Sciences, 26 May 2010)'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 2814462, None, ['Book reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 300369, None, ['Book reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5306731, ['10.1016/0895-9811(90)90010-X'], ['Acknowledge to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1584863, None, ['Errata: Sov. Astron. Lett. 10, No. 3 (1984)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 20790656, None, ['2020 December Meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2354243, None, ['2004 January meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1039413, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1668284, None, ['Society Business'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2354253, None, ['2004 February meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5580414, ['10.1016/0895-9811(92)90032-T'], ['Acknowledgement to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5438171, ['10.1016/0895-9811(91)90011-9'], ['Acknowledgement to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1710964, None, ['Pulsars'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047797, None, ['Princeton Observatory Publications'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047725, None, ['A Correction'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047679, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047662, None, ['Observations on Shadow bands'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1678393, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 8924931, ['10.3367/UFNe.0180.201006g.0647'], ['CONFERENCES AND SYMPOSIA:  Nuclear physics, lasers, and medicine(Scientific session of the General Meeting of the Physical Sciences Division of the Russian Academy of Sciences, 14 December 2009)'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1001989, None, ['Report of the Council on the Work of the Session, October 1, 1907, to September 30, 1908, to be Presented to the Members of the Association at the Annual General Meeting, October 28, 1908'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5580479, ['10.1016/0895-9811(92)90021-P'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5580381, ['10.1016/0895-9811(92)90050-9'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5580375, ['10.1016/0895-9811(92)90011-M'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5864810, ['10.1016/0895-9811(94)90037-X'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1017554, None, ['Notes for Observers'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2215443, None, ['Annual Report of the SAAO 1999'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 920385, ['10.1002/asna.18610540202'], ['Beobachtungen der Sonnenfinsterniss vom 18. Juli d. J. in Desierto de las Palmas, angestellt von der Commission der Königl. Sternwarte zu Madrid. Aus der "Comunicacion del Director del Observatorio de Madrid al Comisario régio del Mismo", vom Herrn Verfasser für die Astr. Nachr. mitgetheilt'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 7264530, ['10.1016/S0375-9474(03)00637-7'], ['Appendix: Members of collaborations'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1579917, None, ['Royal Greenwich Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1611103, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1713865, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4276792, ['10.1016/0370-1573(80)90173-8'], ['Physics results'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19142897, ['10.1016/0273-1177(87)90389-9'], ['Current status of satellite remote sensing and related data systems'], ['astronomy'], ['ARTICLE', 'ESOURCE', 'REFEREED', 'TOC']
# Got none: pub.aff 1039404, None, ['Variable Star Observations: Variable star observations, April 20; Monthly report of the American Association of Variable Star Observers'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 3913934, ['10.1016/S0090-3752(76)80053-1'], ['Key numbers and key words'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 3996060, ['10.1016/S0090-3752(77)80003-3'], ['Reaction index'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1856165, None, ['55. Annual Meeting of the Meteoritical Society, Copenhagen (Denmark), 27 - 31 Jul 1992.'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4860690, ['10.1016/0370-2693(86)91663-1'], ['Abbreviations used in the full listings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1942577, ['10.1007/BF00712488'], ['Preface'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED', 'TOC']
# Got none: pub.aff 3831377, ['10.1016/S0090-3752(75)80025-1'], ['Reaction index'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 2566351, ['10.1007/s11207-008-9168-x'], ['Preface: A Topical Issue on Solar Image Analysis and Visualization'], ['astronomy'], ['ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 1122088, None, ['William Herschel, 1738-1822'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2763708, ['10.3367/UFNe.0182.201209e.0999'], ['Challenges in astrophysics (Scientific session of the Physical Sciences Division of the Russian Academy of Sciences, 25 January 2012)'], ['astronomy', 'physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 9813486, ['10.1119/1.4928369'], ['Magnetic field lines on the Sun'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 776098, None, ['2014 February meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2711577, None, ['RAS Meeting of 2100 May 13'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4412281, ['10.1016/0010-4655(82)90036-4'], ['Erratum notice'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 18918317, ['10.1103/Physics.7.s65'], ['Unexpected Impact from Medium-Sized Solar Flare'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5530417, ['10.1016/0010-4655(92)90157-T'], ['Erratum notice'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 15268446, ['10.1016/S0262-4079(18)31290-9'], ['Tornadoes on sun threaten Earth'], ['general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 8924876, ['10.3367/UFNe.0180.201009f.0973'], ['CONFERENCES AND SYMPOSIA Commemoration of the 85th birthday of S I Syrovatskii(Scientific session of the Physical Sciences Division of the Russian Academy of Sciences, 26 May 2010)'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 2814462, None, ['Book reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 300369, None, ['Book reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5306731, ['10.1016/0895-9811(90)90010-X'], ['Acknowledge to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1584863, None, ['Errata: Sov. Astron. Lett. 10, No. 3 (1984)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 20790656, None, ['2020 December Meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2354243, None, ['2004 January meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1039413, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1668284, None, ['Society Business'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2354253, None, ['2004 February meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5580414, ['10.1016/0895-9811(92)90032-T'], ['Acknowledgement to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5438171, ['10.1016/0895-9811(91)90011-9'], ['Acknowledgement to reviewers'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1710964, None, ['Pulsars'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047797, None, ['Princeton Observatory Publications'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047725, None, ['A Correction'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047679, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047662, None, ['Observations on Shadow bands'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1678393, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 8924931, ['10.3367/UFNe.0180.201006g.0647'], ['CONFERENCES AND SYMPOSIA:  Nuclear physics, lasers, and medicine(Scientific session of the General Meeting of the Physical Sciences Division of the Russian Academy of Sciences, 14 December 2009)'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1001989, None, ['Report of the Council on the Work of the Session, October 1, 1907, to September 30, 1908, to be Presented to the Members of the Association at the Annual General Meeting, October 28, 1908'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 5580479, ['10.1016/0895-9811(92)90021-P'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5580381, ['10.1016/0895-9811(92)90050-9'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5580375, ['10.1016/0895-9811(92)90011-M'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 5864810, ['10.1016/0895-9811(94)90037-X'], ['Upcoming meetings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1017554, None, ['Notes for Observers'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2215443, None, ['Annual Report of the SAAO 1999'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 920385, ['10.1002/asna.18610540202'], ['Beobachtungen der Sonnenfinsterniss vom 18. Juli d. J. in Desierto de las Palmas, angestellt von der Commission der Königl. Sternwarte zu Madrid. Aus der "Comunicacion del Director del Observatorio de Madrid al Comisario régio del Mismo", vom Herrn Verfasser für die Astr. Nachr. mitgetheilt'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 7264530, ['10.1016/S0375-9474(03)00637-7'], ['Appendix: Members of collaborations'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1579917, None, ['Royal Greenwich Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1611103, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1713865, None, ['South African Astronomical Observatory (Reports of Observatories)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4276792, ['10.1016/0370-1573(80)90173-8'], ['Physics results'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 19142897, ['10.1016/0273-1177(87)90389-9'], ['Current status of satellite remote sensing and related data systems'], ['astronomy'], ['ARTICLE', 'ESOURCE', 'REFEREED', 'TOC']
# Got none: pub.aff 1039404, None, ['Variable Star Observations: Variable star observations, April 20; Monthly report of the American Association of Variable Star Observers'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 3913934, ['10.1016/S0090-3752(76)80053-1'], ['Key numbers and key words'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 3996060, ['10.1016/S0090-3752(77)80003-3'], ['Reaction index'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1856165, None, ['55. Annual Meeting of the Meteoritical Society, Copenhagen (Denmark), 27 - 31 Jul 1992.'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 4860690, ['10.1016/0370-2693(86)91663-1'], ['Abbreviations used in the full listings'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1942577, ['10.1007/BF00712488'], ['Preface'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED', 'TOC']
# Got none: pub.aff 3831377, ['10.1016/S0090-3752(75)80025-1'], ['Reaction index'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 18779649, ['10.1038/d41586-020-00360-6'], ['CRISPR enhancement, coronavirus source and a controversial appointment'], ['astronomy', 'general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1744884, None, ['Retirement of Prof A H Jarrett'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED', 'TOC']
# Got none: pub.aff 2461039, None, ['2005 October meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 15508523, None, ['Book reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 994348, None, ['Notices of the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 994275, None, ['Astronomical Publications'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 19257847, ['10.1038/d41586-020-02146-2'], ['Closest Sun shot, methane rising and a Plan S development'], ['astronomy', 'general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1089336, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1162932, None, ['Communications to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 11193130, ['10.1016/S0262-4079(10)60442-3'], ['Earth-hunter makes the cut'], ['general'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 20790678, None, ['2021 January Meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2406814, None, ['2005 April 7 meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1011700, ['10.1093/mnras/71.5.454'], ['Orbits, On multiple solutions in the determination of Second note'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 1028427, ['10.1093/mnras/78.5.343'], ['Society Business: Presents announced; Fellows elected'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 976748, None, ['Duner and Scheiner on stellar evolution'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1017622, ['10.1086/122223'], ['Notes from Pacific Coast Observatories'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 981333, None, ['Spectroscopic Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2663960, None, ['Here and There'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1208531, None, ['Letters to the Editor'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1040770, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 954111, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2655287, ['10.1177/002182861004100414'], ['Book Review: The Greatest Comets in History'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1282030, None, ['Letters to the Editor'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 937996, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 997938, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 932219, None, ["Annales de l'Observatoire de Paris"], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 998008, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 937867, None, ['Astronomical memoranda, 1880, October'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1349776, ['10.1177/002182867600700313'], ['Commission 41 at Grenoble'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 936898, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1047563, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1354463, None, ['The structure and origin of comets'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 976250, ['10.1093/mnras/58.9.473'], ['Gauss, enquiry for letters of'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 1006921, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1020168, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 976444, ['10.1086/121221'], ['First Award of the BRUCE Medal'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1010266, None, ['Meetings of the Society at Peterborough'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2663931, None, ['Here and There'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1784418, None, ['Herer and there'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1188578, None, ['Supplementary catalogue of cometary orbits 1965'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1003745, None, ['1908 March 13 meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2806425, None, ['Reviews/Critiques'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1080017, None, ['1936 January 31 geophysical discussion'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1232283, ['10.1007/BF00153569'], ['Abstracts of forthcoming papers'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 976271, ['10.1093/mnras/58.8.472'], ['Errata'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 1017166, None, ['1913 November 14 meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1038466, None, ['Meetings of the Society at Winnipeg'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2663952, None, ["Notes: Young astrophysicists' prize"], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1569979, None, ["Notes- Two Victoria Astronomers Honoured; J. S. Plaskett and the Study of History Dr. A. V. Douglas Halley's Comet Seventy-Five Years Ago"], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1092111, None, ['Astronomical Query'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 937477, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1028916, None, ['Astronomical phenomena in 1918'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 976384, ['10.1093/mnras/58.4.208'], ["Periodic orbits, Council note on G. H. Darwin's researches on"], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 971470, None, ['notes on some points connected with the Progress of Astronomy'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 971268, ['10.1093/mnras/56.5.251'], ['Council note on the discovery of Comets, 1895'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 968344, None, ['New Books and Memoirs'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 936257, ['10.1093/mnras/38.4.155'], ['Associates deceased :- Le Verrier, U. J.'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 1096613, None, ['Exhibitors and Exhibits, 1943 April 28'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1092115, None, ['Review'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 997645, None, ['1906 March 28 meeting of the British Astronomical Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 966631, None, ['Practical Suggestions'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1034063, ['10.1086/122936'], ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 975968, None, ['Reports of the Branches'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2666621, ['10.1088/0031-9120/45/5/M02'], ['People Interview: Solar physics blasts into space'], ['astronomy', 'physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 968786, ['10.1093/mnras/55.4.233'], ['Comets of 1894, Council note on the'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 2254894, None, ['News Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 16242038, ['10.1103/Physics.12.84'], ['Physics from the Moon'], ['physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 1114166, None, ['Reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1089779, None, ['Paper Communicated to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1073191, None, ['Meetings of the Society-Toronto'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1006156, None, ['1909 March 31 meeting of the British Astronomical Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 981587, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1066767, None, ['Papers Communicated to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1019790, None, ['General Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 971737, None, ['Publications'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1124043, None, ['Reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2215453, None, ['SALT update (news note)'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1020366, ['10.1086/122310'], ['Abstracts from Astronomical Publications'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1078343, None, ['Papers Communicated to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2346014, None, ['News Notes / En manchettes; Meteoroids 2004 Conference; Quantum Computing Smaller, Faster, and More Powerful; Studying Antihydrogen; Northern Bruce Peninsula Proclaimed a "Dark Sky Community"; By the Light of a Quasi Moon'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1008176, None, ['Astronomical Publications'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2452966, None, ['News Notes / En machettes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1111240, None, ['Papers Communicated to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1066806, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1013311, None, ['Memoranda for Observers'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2132392, None, ['1999 May 14 meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 996330, None, ['Astronomical Publications'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 980577, None, ['New Books and Memoirs'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1119197, None, ['Papers Communicated to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2497326, None, ["Reviews: Comets II; The Last of the Great Observatories: Spitzer and the Era of Faster, Better, Cheaper at NASA; Canada in Space: The People &amp; Stories behind Canada's Role in the Exploration of Space"], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1095485, None, ['Communications and Comments: Comments on two papers in the April issue; Origin of the planets by electrostatic ejection'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1050441, None, ['1926 March 12 meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 987136, None, ['Papers communicated to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2852977, None, ['2015 October meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1130557, None, ['Comet Arend-Roland, 1956h'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1113500, None, ['Notes'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2358406, ['10.1088/0031-9120/39/6/M01'], ['News'], ['astronomy', 'physics'], ['ARTICLE', 'ESOURCE', 'REFEREED']
# Got none: pub.aff 776127, None, ['2013 July (NAM) meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1093604, None, ['Communications and Comments: Electromagnetic Vortices'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1090803, None, ['Meetings of the Society-Victoria, Vancouver, Edmonton, Winnipeg Toronto'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2853304, None, ['2015 December meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2306216, None, ['2003 March 14 meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 20790656, None, ['2020 December Meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1711094, None, ['1988 January 8 meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1009527, ['10.1093/mnras/71.1.68'], ['Mean areas and heliographic latitudes of sun-spots in the years 1907, 1908, and 1909, Greenwich, Royal Observatory'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'PUB_OPENACCESS', 'REFEREED']
# Got none: pub.aff 2853014, None, ['Book reviews'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 977023, ['10.1086/121269'], ['Notices from the Lick Observatory'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2853371, None, ['2016 January meeting of the RAS'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1040766, None, ['Meetings of the Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 925465, None, ['Report of the Council'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 998504, None, ['Papers Communicated to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 998417, None, ['Papers Communicated to the Association'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2217108, None, ['2000 October meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 2172940, None, ['1999 December 10 meeting of the Royal Astronomical Society'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# Got none: pub.aff 1164851, None, ['Problems of the interstellar medium and galactic structure'], ['astronomy'], ['ADS_OPENACCESS', 'ARTICLE', 'ESOURCE', 'OPENACCESS', 'REFEREED']
# ...
# Gaia                     101450                5450            12621
# MEX                       56150                3653             3020
# Dawn                      60885                 800             4317
# HST                      555500               56644            17472
# Chandra                  293000                8700            13047
#
#               years_since_launch  footprint_per_paper  \
# mission
# PSP                     3.389041                   35
# SDO                    11.893151                   14
# SolarOrbiter            1.890411                   16
# SOHO                   26.098630                    6
# MMS                     6.808219                   17
# Cluster                21.473973                   26
# Cassini                24.227397                   49
# DoubleStar             18.019178                  298
# Demeter                17.517808                   25
# STEREO                 15.191781                   13
# ACE                    24.367123                    1
# IMP_8                  48.128767                    6
# Geotail                29.457534                    0
# Wind                   27.101370                   56
# TIMED                  20.079452                   13
# VEX                     6.956164                   39
# THEMIS                 14.879452                   27
# Juno                   10.413699                  243
# Rosetta                17.843836                   83
# Galileo                32.224658                   81
# Gaia                    8.038356                   19
# MEX                    18.594521                   15
# Dawn                   14.104110                   76
# HST                    31.794521                   10
# Chandra                22.457534                   34
#
#               total_publications_LPP_2019  total_publications_LPP_2020  \
# mission
# PSP                                     5                           12
# SDO                                     0                            1
# SolarOrbiter                            3                           10
# SOHO                                    2                            3
# MMS                                    31                           19
# Cluster                                 1                            5
# Cassini                                 1                            1
# DoubleStar                              0                            0
# Demeter                                 1                            0
# STEREO                                  1                            4
# ACE                                     5                           10
# IMP_8                                   0                            0
# Geotail                                29                           17
# Wind                                    0                            3
# TIMED                                   0                            1
# VEX                                     3                            3
# THEMIS                                  1                            1
# Juno                                    1                            0
# Rosetta                                 1                            2
# Galileo                                 0                            1
# Gaia                                    0                            0
# MEX                                     1                            4
# Dawn                                    0                            0
# HST                                     0                            2
# Chandra                                 0                            0
#
#               total_publications_LPP_2021  total_publications_LPP  \
# mission
# PSP                                    32                      51
# SDO                                     2                       6
# SolarOrbiter                           31                      67
# SOHO                                    6                      22
# MMS                                    31                     155
# Cluster                                10                     108
# Cassini                                 4                      12
# DoubleStar                              0                       1
# Demeter                                 0                       3
# STEREO                                  8                      39
# ACE                                     8                      65
# IMP_8                                   2                       7
# Geotail                                40                     301
# Wind                                    3                      10
# TIMED                                   2                       8
# VEX                                     6                      13
# THEMIS                                  4                      34
# Juno                                    0                       2
# Rosetta                                 0                       4
# Galileo                                 0                       3
# Gaia                                    0                       1
# MEX                                     3                      13
# Dawn                                    1                       1
# HST                                     0                      15
# Chandra                                 0                       3
#
#               CO2e_mass_LPP_2019  ...  CO2e_mass_IRAP_2020  \
# mission                           ...
# PSP                          174  ...                 1186
# SDO                            0  ...                  301
# SolarOrbiter                   0  ...                  506
# SOHO                          12  ...                   99
# MMS                          523  ...                  354
# Cluster                       26  ...                   77
# Cassini                       49  ...                   49
# DoubleStar                     0  ...                  298
# Demeter                       25  ...                    0
# STEREO                        13  ...                  304
# ACE                            6  ...                    9
# IMP_8                          0  ...                    6
# Geotail                        8  ...                   20
# Wind                           0  ...                  169
# TIMED                          0  ...                    0
# VEX                          117  ...                  272
# THEMIS                        27  ...                   80
# Juno                         243  ...                 1213
# Rosetta                       83  ...                  167
# Galileo                        0  ...                   81
# Gaia                           0  ...                  168
# MEX                           15  ...                  169
# Dawn                           0  ...                    0
# HST                            0  ...                  441
# Chandra                        0  ...                  404
#
#               total_publications_IRAP_2021  CO2e_mass_IRAP_2021  \
# mission
# PSP                                     41                 1430
# SDO                                     23                  330
# SolarOrbiter                            47                  767
# SOHO                                    22                  137
# MMS                                     17                  287
# Cluster                                  9                  230
# Cassini                                  3                  147
# DoubleStar                               1                  298
# Demeter                                  0                    0
# STEREO                                  20                  254
# ACE                                     18                   21
# IMP_8                                    1                    6
# Geotail                                 85                   25
# Wind                                     2                  113
# TIMED                                    0                    0
# VEX                                      8                  311
# THEMIS                                   2                   53
# Juno                                     7                 1698
# Rosetta                                  2                  167
# Galileo                                  1                   81
# Gaia                                    15                  279
# MEX                                      8                  123
# Dawn                                     1                   76
# HST                                     50                  490
# Chandra                                  5                  168
#
#               total_publications_LPC2E  total_publications_LPC2E_2019  \
# mission
# PSP                                 85                              4
# SDO                                 37                              2
# SolarOrbiter                        47                              2
# SOHO                                34                              4
# MMS                                 22                              1
# Cluster                             37                              0
# Cassini                             16                              0
# DoubleStar                           0                              0
# Demeter                             48                              4
# STEREO                              50                              3
# ACE                                 26                              0
# IMP_8                                4                              0
# Geotail                            125                              7
# Wind                                 6                              1
# TIMED                               21                              1
# VEX                                 10                              0
# THEMIS                              11                              1
# Juno                                 6                              0
# Rosetta                             69                              9
# Galileo                              6                              0
# Gaia                                 4                              2
# MEX                                  7                              0
# Dawn                                 1                              0
# HST                                 14                              2
# Chandra                              4                              0
#
#               CO2e_mass_LPC2E_2019  total_publications_LPC2E_2020  \
# mission
# PSP                            140                             47
# SDO                             29                             12
# SolarOrbiter                     0                             17
# SOHO                            25                              3
# MMS                             17                              6
# Cluster                          0                              4
# Cassini                          0                              0
# DoubleStar                       0                              0
# Demeter                         98                              3
# STEREO                          38                             18
# ACE                              0                              6
# IMP_8                            0                              1
# Geotail                          2                             24
# Wind                            56                              1
# TIMED                           13                              1
# VEX                              0                              2
# THEMIS                          27                              0
# Juno                             0                              1
# Rosetta                        750                             10
# Galileo                          0                              1
# Gaia                            37                              0
# MEX                              0                              2
# Dawn                             0                              0
# HST                             20                              2
# Chandra                          0                              0
#
#               CO2e_mass_LPC2E_2020  total_publications_LPC2E_2021  \
# mission
# PSP                           1639                             34
# SDO                            172                              1
# SolarOrbiter                   277                             21
# SOHO                            19                              3
# MMS                            101                              6
# Cluster                        102                              0
# Cassini                          0                              0
# DoubleStar                       0                              0
# Demeter                         74                              6
# STEREO                         228                             12
# ACE                              7                              3
# IMP_8                            6                              0
# Geotail                          7                             20
# Wind                            56                              2
# TIMED                           13                              0
# VEX                             78                              2
# THEMIS                           0                              0
# Juno                           243                              0
# Rosetta                        833                              2
# Galileo                         81                              0
# Gaia                             0                              0
# MEX                             31                              0
# Dawn                             0                              0
# HST                             20                              0
# Chandra                          0                              0
#
#               CO2e_mass_LPC2E_2021
# mission
# PSP                           1186
# SDO                             14
# SolarOrbiter                   343
# SOHO                            19
# MMS                            101
# Cluster                          0
# Cassini                          0
# DoubleStar                       0
# Demeter                        148
# STEREO                         152
# ACE                              3
# IMP_8                            0
# Geotail                          6
# Wind                           113
# TIMED                            0
# VEX                             78
# THEMIS                           0
# Juno                             0
# Rosetta                        167
# Galileo                          0
# Gaia                             0
# MEX                              0
# Dawn                             0
# HST                              0
# Chandra                          0
#
# [25 rows x 26 columns]

# %%
df
# Out:
#               mission_footprint  total_publications  anual_footprint  \
# mission
# PSP                       34250                 982            10106
# SDO                      155000               10798            13033
# SolarOrbiter              90000                5517            47609
# SOHO                      92500               14888             3544
# MMS                       68000                4034             9988
# Cluster                   60000                2343             2794
# Cassini                  285600                5834            11788
# DoubleStar                28000                  94             1554
# Demeter                    6500                 264              371
# STEREO                    62000                4891             4081
# ACE                       37850               33222             1553
# IMP_8                     18550                2902              385
# Geotail                   49000              168234             1663
# Wind                      62500                1110             2306
# TIMED                     33000                2528             1643
# VEX                       63500                1634             9129
# THEMIS                    31500                1186             2117
# Juno                     181250                 747            17405
# Rosetta                  150000                1801             8406
# Galileo                  128000                1583             3972
# Gaia                     101450                5450            12621
# MEX                       56150                3653             3020
# Dawn                      60885                 800             4317
# HST                      555500               56644            17472
# Chandra                  293000                8700            13047
#
#               years_since_launch  footprint_per_paper  \
# mission
# PSP                     3.389041                   35
# SDO                    11.893151                   14
# SolarOrbiter            1.890411                   16
# SOHO                   26.098630                    6
# MMS                     6.808219                   17
# Cluster                21.473973                   26
# Cassini                24.227397                   49
# DoubleStar             18.019178                  298
# Demeter                17.517808                   25
# STEREO                 15.191781                   13
# ACE                    24.367123                    1
# IMP_8                  48.128767                    6
# Geotail                29.457534                    0
# Wind                   27.101370                   56
# TIMED                  20.079452                   13
# VEX                     6.956164                   39
# THEMIS                 14.879452                   27
# Juno                   10.413699                  243
# Rosetta                17.843836                   83
# Galileo                32.224658                   81
# Gaia                    8.038356                   19
# MEX                    18.594521                   15
# Dawn                   14.104110                   76
# HST                    31.794521                   10
# Chandra                22.457534                   34
#
#               total_publications_LPP_2019  total_publications_LPP_2020  \
# mission
# PSP                                     5                           12
# SDO                                     0                            1
# SolarOrbiter                            3                           10
# SOHO                                    2                            3
# MMS                                    31                           19
# Cluster                                 1                            5
# Cassini                                 1                            1
# DoubleStar                              0                            0
# Demeter                                 1                            0
# STEREO                                  1                            4
# ACE                                     5                           10
# IMP_8                                   0                            0
# Geotail                                29                           17
# Wind                                    0                            3
# TIMED                                   0                            1
# VEX                                     3                            3
# THEMIS                                  1                            1
# Juno                                    1                            0
# Rosetta                                 1                            2
# Galileo                                 0                            1
# Gaia                                    0                            0
# MEX                                     1                            4
# Dawn                                    0                            0
# HST                                     0                            2
# Chandra                                 0                            0
#
#               total_publications_LPP_2021  total_publications_LPP  \
# mission
# PSP                                    32                      51
# SDO                                     2                       6
# SolarOrbiter                           31                      67
# SOHO                                    6                      22
# MMS                                    31                     155
# Cluster                                10                     108
# Cassini                                 4                      12
# DoubleStar                              0                       1
# Demeter                                 0                       3
# STEREO                                  8                      39
# ACE                                     8                      65
# IMP_8                                   2                       7
# Geotail                                40                     301
# Wind                                    3                      10
# TIMED                                   2                       8
# VEX                                     6                      13
# THEMIS                                  4                      34
# Juno                                    0                       2
# Rosetta                                 0                       4
# Galileo                                 0                       3
# Gaia                                    0                       1
# MEX                                     3                      13
# Dawn                                    1                       1
# HST                                     0                      15
# Chandra                                 0                       3
#
#               CO2e_mass_LPP_2019  ...  CO2e_mass_IRAP_2020  \
# mission                           ...
# PSP                          174  ...                 1186
# SDO                            0  ...                  301
# SolarOrbiter                   0  ...                  506
# SOHO                          12  ...                   99
# MMS                          523  ...                  354
# Cluster                       26  ...                   77
# Cassini                       49  ...                   49
# DoubleStar                     0  ...                  298
# Demeter                       25  ...                    0
# STEREO                        13  ...                  304
# ACE                            6  ...                    9
# IMP_8                          0  ...                    6
# Geotail                        8  ...                   20
# Wind                           0  ...                  169
# TIMED                          0  ...                    0
# VEX                          117  ...                  272
# THEMIS                        27  ...                   80
# Juno                         243  ...                 1213
# Rosetta                       83  ...                  167
# Galileo                        0  ...                   81
# Gaia                           0  ...                  168
# MEX                           15  ...                  169
# Dawn                           0  ...                    0
# HST                            0  ...                  441
# Chandra                        0  ...                  404
#
#               total_publications_IRAP_2021  CO2e_mass_IRAP_2021  \
# mission
# PSP                                     41                 1430
# SDO                                     23                  330
# SolarOrbiter                            47                  767
# SOHO                                    22                  137
# MMS                                     17                  287
# Cluster                                  9                  230
# Cassini                                  3                  147
# DoubleStar                               1                  298
# Demeter                                  0                    0
# STEREO                                  20                  254
# ACE                                     18                   21
# IMP_8                                    1                    6
# Geotail                                 85                   25
# Wind                                     2                  113
# TIMED                                    0                    0
# VEX                                      8                  311
# THEMIS                                   2                   53
# Juno                                     7                 1698
# Rosetta                                  2                  167
# Galileo                                  1                   81
# Gaia                                    15                  279
# MEX                                      8                  123
# Dawn                                     1                   76
# HST                                     50                  490
# Chandra                                  5                  168
#
#               total_publications_LPC2E  total_publications_LPC2E_2019  \
# mission
# PSP                                 85                              4
# SDO                                 37                              2
# SolarOrbiter                        47                              2
# SOHO                                34                              4
# MMS                                 22                              1
# Cluster                             37                              0
# Cassini                             16                              0
# DoubleStar                           0                              0
# Demeter                             48                              4
# STEREO                              50                              3
# ACE                                 26                              0
# IMP_8                                4                              0
# Geotail                            125                              7
# Wind                                 6                              1
# TIMED                               21                              1
# VEX                                 10                              0
# THEMIS                              11                              1
# Juno                                 6                              0
# Rosetta                             69                              9
# Galileo                              6                              0
# Gaia                                 4                              2
# MEX                                  7                              0
# Dawn                                 1                              0
# HST                                 14                              2
# Chandra                              4                              0
#
#               CO2e_mass_LPC2E_2019  total_publications_LPC2E_2020  \
# mission
# PSP                            140                             47
# SDO                             29                             12
# SolarOrbiter                     0                             17
# SOHO                            25                              3
# MMS                             17                              6
# Cluster                          0                              4
# Cassini                          0                              0
# DoubleStar                       0                              0
# Demeter                         98                              3
# STEREO                          38                             18
# ACE                              0                              6
# IMP_8                            0                              1
# Geotail                          2                             24
# Wind                            56                              1
# TIMED                           13                              1
# VEX                              0                              2
# THEMIS                          27                              0
# Juno                             0                              1
# Rosetta                        750                             10
# Galileo                          0                              1
# Gaia                            37                              0
# MEX                              0                              2
# Dawn                             0                              0
# HST                             20                              2
# Chandra                          0                              0
#
#               CO2e_mass_LPC2E_2020  total_publications_LPC2E_2021  \
# mission
# PSP                           1639                             34
# SDO                            172                              1
# SolarOrbiter                   277                             21
# SOHO                            19                              3
# MMS                            101                              6
# Cluster                        102                              0
# Cassini                          0                              0
# DoubleStar                       0                              0
# Demeter                         74                              6
# STEREO                         228                             12
# ACE                              7                              3
# IMP_8                            6                              0
# Geotail                          7                             20
# Wind                            56                              2
# TIMED                           13                              0
# VEX                             78                              2
# THEMIS                           0                              0
# Juno                           243                              0
# Rosetta                        833                              2
# Galileo                         81                              0
# Gaia                             0                              0
# MEX                             31                              0
# Dawn                             0                              0
# HST                             20                              0
# Chandra                          0                              0
#
#               CO2e_mass_LPC2E_2021
# mission
# PSP                           1186
# SDO                             14
# SolarOrbiter                   343
# SOHO                            19
# MMS                            101
# Cluster                          0
# Cassini                          0
# DoubleStar                       0
# Demeter                        148
# STEREO                         152
# ACE                              3
# IMP_8                            0
# Geotail                          6
# Wind                           113
# TIMED                            0
# VEX                             78
# THEMIS                           0
# Juno                             0
# Rosetta                        167
# Galileo                          0
# Gaia                             0
# MEX                              0
# Dawn                             0
# HST                              0
# Chandra                          0
#
# [25 rows x 26 columns]

# %%
df.to_excel("space_missions_carbon_footprint.xlsx")
